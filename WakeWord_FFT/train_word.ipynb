# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
print(tf.__version__)
# Out:
# 2.13.1

# %%
# CSV 파일 읽어오기
nothing_data = pd.read_csv('nothing.csv', header=None)
wiznet_data = pd.read_csv('huhu.csv', header=None)
you_data = pd.read_csv('huu.csv', header=None)

# %%
# 데이터 병합 및 레이블 할당
data = np.vstack((nothing_data, wiznet_data, you_data))
labels = np.concatenate((np.zeros(len(nothing_data)), np.ones(len(wiznet_data)), np.ones(len(you_data))*2))

# %%
# 학습 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# 입력 데이터 크기 확인
input_shape = X_train.shape[1]

# %%
# 모델 구성
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(input_shape,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# 모델 평가
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 335/335 [==============================] - 1s 1ms/step - loss: 0.6394 - accuracy: 0.7528 - val_loss: 0.5454 - val_accuracy: 0.8047
# Epoch 2/50
# 335/335 [==============================] - 0s 818us/step - loss: 0.5419 - accuracy: 0.7989 - val_loss: 0.5202 - val_accuracy: 0.8092
# Epoch 3/50
# 335/335 [==============================] - 0s 847us/step - loss: 0.5273 - accuracy: 0.8064 - val_loss: 0.5541 - val_accuracy: 0.8085
# Epoch 4/50
# 335/335 [==============================] - 0s 850us/step - loss: 0.5107 - accuracy: 0.8123 - val_loss: 0.5579 - val_accuracy: 0.8085
# Epoch 5/50
# 335/335 [==============================] - 0s 833us/step - loss: 0.5045 - accuracy: 0.8126 - val_loss: 0.7672 - val_accuracy: 0.5346
# Epoch 6/50
# 335/335 [==============================] - 0s 869us/step - loss: 0.4932 - accuracy: 0.8173 - val_loss: 0.5312 - val_accuracy: 0.8178
# Epoch 7/50
# 335/335 [==============================] - 0s 851us/step - loss: 0.4883 - accuracy: 0.8235 - val_loss: 0.5918 - val_accuracy: 0.8043
# Epoch 8/50
# 335/335 [==============================] - 0s 835us/step - loss: 0.4772 - accuracy: 0.8255 - val_loss: 0.4849 - val_accuracy: 0.8242
# Epoch 9/50
# 335/335 [==============================] - 0s 840us/step - loss: 0.4777 - accuracy: 0.8247 - val_loss: 0.5604 - val_accuracy: 0.7695
# Epoch 10/50
# 335/335 [==============================] - 0s 858us/step - loss: 0.4759 - accuracy: 0.8246 - val_loss: 0.5423 - val_accuracy: 0.8006
# Epoch 11/50
# 335/335 [==============================] - 0s 850us/step - loss: 0.4765 - accuracy: 0.8246 - val_loss: 0.5062 - val_accuracy: 0.8043
# Epoch 12/50
# 335/335 [==============================] - 0s 853us/step - loss: 0.4588 - accuracy: 0.8297 - val_loss: 0.4820 - val_accuracy: 0.8114
# Epoch 13/50
# 335/335 [==============================] - 0s 827us/step - loss: 0.4540 - accuracy: 0.8304 - val_loss: 0.4768 - val_accuracy: 0.8219
# Epoch 14/50
# 335/335 [==============================] - 0s 823us/step - loss: 0.4527 - accuracy: 0.8308 - val_loss: 0.4529 - val_accuracy: 0.8309
# Epoch 15/50
# 335/335 [==============================] - 0s 825us/step - loss: 0.4510 - accuracy: 0.8332 - val_loss: 0.5290 - val_accuracy: 0.8100
# Epoch 16/50
# 335/335 [==============================] - 0s 837us/step - loss: 0.4482 - accuracy: 0.8327 - val_loss: 0.4608 - val_accuracy: 0.8182
# Epoch 17/50
# 335/335 [==============================] - 0s 857us/step - loss: 0.4513 - accuracy: 0.8306 - val_loss: 0.4678 - val_accuracy: 0.8156
# Epoch 18/50
# 335/335 [==============================] - 0s 842us/step - loss: 0.4493 - accuracy: 0.8298 - val_loss: 0.4614 - val_accuracy: 0.8238
# Epoch 19/50
# 335/335 [==============================] - 0s 826us/step - loss: 0.4467 - accuracy: 0.8302 - val_loss: 0.4743 - val_accuracy: 0.8186
# Epoch 20/50
# 335/335 [==============================] - 0s 865us/step - loss: 0.4417 - accuracy: 0.8343 - val_loss: 0.4625 - val_accuracy: 0.8167
# Epoch 21/50
# 335/335 [==============================] - 0s 835us/step - loss: 0.4416 - accuracy: 0.8337 - val_loss: 0.5329 - val_accuracy: 0.7972
# Epoch 22/50
# 335/335 [==============================] - 0s 840us/step - loss: 0.4399 - accuracy: 0.8337 - val_loss: 0.4547 - val_accuracy: 0.8283
# Epoch 23/50
# 335/335 [==============================] - 0s 838us/step - loss: 0.4365 - accuracy: 0.8355 - val_loss: 0.4641 - val_accuracy: 0.8197
# Epoch 24/50
# 335/335 [==============================] - 0s 842us/step - loss: 0.4380 - accuracy: 0.8361 - val_loss: 0.4518 - val_accuracy: 0.8260
# Epoch 25/50
# 335/335 [==============================] - 0s 842us/step - loss: 0.4414 - accuracy: 0.8311 - val_loss: 0.4435 - val_accuracy: 0.8245
# Epoch 26/50
# 335/335 [==============================] - 0s 869us/step - loss: 0.4328 - accuracy: 0.8359 - val_loss: 0.4582 - val_accuracy: 0.8223
# Epoch 27/50
# 335/335 [==============================] - 0s 864us/step - loss: 0.4338 - accuracy: 0.8330 - val_loss: 0.4492 - val_accuracy: 0.8227
# Epoch 28/50
# 335/335 [==============================] - 0s 959us/step - loss: 0.4277 - accuracy: 0.8342 - val_loss: 0.4403 - val_accuracy: 0.8294
# Epoch 29/50
# 335/335 [==============================] - 0s 846us/step - loss: 0.4328 - accuracy: 0.8350 - val_loss: 0.4626 - val_accuracy: 0.8365
# Epoch 30/50
# 335/335 [==============================] - 0s 879us/step - loss: 0.4283 - accuracy: 0.8361 - val_loss: 0.4441 - val_accuracy: 0.8272
# Epoch 31/50
# 335/335 [==============================] - 0s 842us/step - loss: 0.4278 - accuracy: 0.8372 - val_loss: 0.4560 - val_accuracy: 0.8238
# Epoch 32/50
# 335/335 [==============================] - 0s 825us/step - loss: 0.4325 - accuracy: 0.8361 - val_loss: 0.4380 - val_accuracy: 0.8302
# Epoch 33/50
# 335/335 [==============================] - 0s 819us/step - loss: 0.4265 - accuracy: 0.8364 - val_loss: 0.4378 - val_accuracy: 0.8302
# Epoch 34/50
# 335/335 [==============================] - 0s 827us/step - loss: 0.4227 - accuracy: 0.8371 - val_loss: 0.4397 - val_accuracy: 0.8260
# Epoch 35/50
# 335/335 [==============================] - 0s 833us/step - loss: 0.4213 - accuracy: 0.8388 - val_loss: 0.5069 - val_accuracy: 0.8103
# Epoch 36/50
# 335/335 [==============================] - 0s 888us/step - loss: 0.4240 - accuracy: 0.8384 - val_loss: 0.4401 - val_accuracy: 0.8324
# Epoch 37/50
# 335/335 [==============================] - 0s 823us/step - loss: 0.4213 - accuracy: 0.8397 - val_loss: 0.4273 - val_accuracy: 0.8350
# Epoch 38/50
# 335/335 [==============================] - 0s 820us/step - loss: 0.4240 - accuracy: 0.8403 - val_loss: 0.4486 - val_accuracy: 0.8290
# Epoch 39/50
# 335/335 [==============================] - 0s 817us/step - loss: 0.4297 - accuracy: 0.8348 - val_loss: 0.4400 - val_accuracy: 0.8264
# Epoch 40/50
# 335/335 [==============================] - 0s 820us/step - loss: 0.4227 - accuracy: 0.8382 - val_loss: 0.4409 - val_accuracy: 0.8287
# Epoch 41/50
# 335/335 [==============================] - 0s 821us/step - loss: 0.4204 - accuracy: 0.8420 - val_loss: 0.5329 - val_accuracy: 0.8122
# Epoch 42/50
# 335/335 [==============================] - 0s 822us/step - loss: 0.4217 - accuracy: 0.8419 - val_loss: 0.4535 - val_accuracy: 0.8283
# Epoch 43/50
# 335/335 [==============================] - 0s 894us/step - loss: 0.4169 - accuracy: 0.8431 - val_loss: 0.4528 - val_accuracy: 0.8279
# Epoch 44/50
# 335/335 [==============================] - 0s 824us/step - loss: 0.4157 - accuracy: 0.8418 - val_loss: 0.4443 - val_accuracy: 0.8227
# Epoch 45/50
# 335/335 [==============================] - 0s 825us/step - loss: 0.4157 - accuracy: 0.8422 - val_loss: 0.4336 - val_accuracy: 0.8309
# Epoch 46/50
# 335/335 [==============================] - 0s 820us/step - loss: 0.4144 - accuracy: 0.8413 - val_loss: 0.4272 - val_accuracy: 0.8309
# Epoch 47/50
# 335/335 [==============================] - 0s 835us/step - loss: 0.4178 - accuracy: 0.8424 - val_loss: 0.4345 - val_accuracy: 0.8331
# Epoch 48/50
# 335/335 [==============================] - 0s 822us/step - loss: 0.4092 - accuracy: 0.8444 - val_loss: 0.4327 - val_accuracy: 0.8313
# Epoch 49/50
# 335/335 [==============================] - 0s 829us/step - loss: 0.4142 - accuracy: 0.8421 - val_loss: 0.4249 - val_accuracy: 0.8354
# Epoch 50/50
# 335/335 [==============================] - 0s 825us/step - loss: 0.4132 - accuracy: 0.8428 - val_loss: 0.4630 - val_accuracy: 0.8174
# 84/84 [==============================] - 0s 624us/step - loss: 0.4630 - accuracy: 0.8174
# Test accuracy: 0.8174335956573486

# %%
import matplotlib.pyplot as plt
# 손실 그래프 그리기
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.legend()
plt.title('Loss over epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# 정확도 그래프 그리기
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.legend()
plt.title('Accuracy over epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
# TensorFlow Lite 변환# 예를 들어, 변환 과정에서 양자화를 사용하지 않도록 설정
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Acorn\AppData\Local\Temp\tmp_o2jjjjf\assets
# INFO:tensorflow:Assets written to: C:\Users\Acorn\AppData\Local\Temp\tmp_o2jjjjf\assets

# %%
# TensorFlow Lite 모델 저장
with open('voice_recognition_model.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
def representative_dataset_gen():
    for i in range(len(X_train)):
        yield [X_train[i].astype(np.float32)]

# %%
# TensorFlow Lite 변환 및 완전 정수 양자화
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
tflite_quant_model = converter.convert()

# 완전 정수 양자화된 TensorFlow Lite 모델 저장
with open('voice_recognition_model_quant.tflite', 'wb') as f:
    f.write(tflite_quant_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Acorn\AppData\Local\Temp\tmp33e6ky98\assets
# INFO:tensorflow:Assets written to: C:\Users\Acorn\AppData\Local\Temp\tmp33e6ky98\assets
# c:\Users\Acorn\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\convert.py:887: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
